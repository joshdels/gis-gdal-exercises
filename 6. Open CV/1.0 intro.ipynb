# %%
import geopandas as gpd
import geodatasets

# %%
geodatasets.data
# Out:
# {'geoda': {'airbnb': {'url': 'https://geodacenter.github.io/data-and-lab//data/airbnb.zip',
#    'license': 'NA',
#    'attribution': 'Center for Spatial Data Science, University of Chicago',
#    'name': 'geoda.airbnb',
#    'description': 'Airbnb rentals, socioeconomics, and crime in Chicago',
#    'geometry_type': 'Polygon',
#    'nrows': 77,
#    'ncols': 21,
#    'details': 'https://geodacenter.github.io/data-and-lab//airbnb/',
#    'hash': 'a2ab1e3f938226d287dd76cde18c00e2d3a260640dd826da7131827d9e76c824',
#    'filename': 'airbnb.zip'},
#   'atlanta': {'url': 'https://geodacenter.github.io/data-and-lab//data/atlanta_hom.zip',
#    'license': 'NA',
#    'attribution': 'Center for Spatial Data Science, University of Chicago',
#    'name': 'geoda.atlanta',
#    'description': 'Atlanta, GA region homicide counts and rates',
#    'geometry_type': 'Polygon',
#    'nrows': 90,
#    'ncols': 24,
#    'details': 'https://geodacenter.github.io/data-and-lab//atlanta_old/',
# ...

# %%
gdf = gpd.read_file(geodatasets.get_url("geoda airbnb"))
print(gdf.head())
# Out:
#          community     shape_area      shape_len  AREAID  response_r  \
# 0          DOUGLAS  46004621.1581  31027.0545098      35   98.771429
# 1          OAKLAND  16913961.0408  19565.5061533      36   99.200000
# 2      FULLER PARK  19916704.8692           None      37   68.000000
# 3  GRAND BOULEVARD  48492503.1554  28196.8371573      38   94.037037
# 4          KENWOOD  29071741.9283  23325.1679062      39   92.542857
#
#     accept_r  rev_rating    price_pp  room_type  num_spots  ...  crowded  \
# 0  94.514286   87.777778   78.157895   1.789474         38  ...      1.8
# 1  90.105263   88.812500   53.775000   1.850000         20  ...      1.3
# 2        NaN   91.750000   84.000000   1.833333          6  ...      3.2
# 3  83.615385   92.750000  119.533333   1.533333         30  ...      3.3
# 4  88.142857   90.656250   77.991453   1.615385         39  ...      2.4
#
#    dependency  without_hs  unemployed  income_pc  harship_in  num_crimes  \
# ...

# %%
gdf.to_parquet("world.parquet")

# %%
gdf2 = gpd.read_parquet("world.parquet")

print(gdf2.shape)
print(gdf2.crs)
print(gdf2.head(2))
# Out:
# (77, 21)
# {"$schema": "https://proj.org/schemas/v0.7/projjson.schema.json", "type": "GeographicCRS", "name": "WGS 84", "datum": {"type": "GeodeticReferenceFrame", "name": "World Geodetic System 1984", "ellipsoid": {"name": "WGS 84", "semi_major_axis": 6378137, "inverse_flattening": 298.257223563}, "id": {"authority": "EPSG", "code": 6326}}, "coordinate_system": {"subtype": "ellipsoidal", "axis": [{"name": "Longitude", "abbreviation": "lon", "direction": "east", "unit": {"type": "AngularUnit", "name": "Degree", "conversion_factor": 0.0174532925199433}}, {"name": "Latitude", "abbreviation": "lat", "direction": "north", "unit": {"type": "AngularUnit", "name": "Degree", "conversion_factor": 0.0174532925199433}}]}}
#   community     shape_area      shape_len  AREAID  response_r   accept_r  \
# 0   DOUGLAS  46004621.1581  31027.0545098      35   98.771429  94.514286
# 1   OAKLAND  16913961.0408  19565.5061533      36   99.200000  90.105263
#
# ...

# %%
# metadata
import pyarrow.parquet as pq
meta = pq.read_metadata("world.parquet")
print(meta.metadata)
# Out:
# {b'pandas': b'{"index_columns": [{"kind": "range", "name": null, "start": 0, "stop": 77, "step": 1}], "column_indexes": [{"name": null, "field_name": null, "pandas_type": "unicode", "numpy_type": "object", "metadata": {"encoding": "UTF-8"}}], "columns": [{"name": "community", "field_name": "community", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "shape_area", "field_name": "shape_area", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "shape_len", "field_name": "shape_len", "pandas_type": "unicode", "numpy_type": "object", "metadata": null}, {"name": "AREAID", "field_name": "AREAID", "pandas_type": "int64", "numpy_type": "int64", "metadata": null}, {"name": "response_r", "field_name": "response_r", "pandas_type": "float64", "numpy_type": "float64", "metadata": null}, {"name": "accept_r", "field_name": "accept_r", "pandas_type": "float64", "numpy_type": "float64", "metadata": null}, {"name": "rev_rating", "field_name": "re
# ...

# %%
import duckdb

duckdb.sql("INSTALL spatial; LOAD spatial;")

duckdb.sql(r"""
    DESCRIBE SELECT *
    FROM st_read('C:/Users/deleo/Downloads/burleson_landparcels.geojson')
""").show()
# Out:
# ┌──────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │ column_name  │ column_type │  null   │   key   │ default │  extra  │
# │   varchar    │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├──────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ Prop_ID      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ GEO_ID       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ OWNER_NAME   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ NAME_CARE    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ LEGAL_AREA   │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ LGL_AREA_U   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ GIS_AREA     │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ GIS_AREA_U   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ LEGAL_DESC   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
duckdb.sql("SELECT room_type, population  FROM 'world.parquet' WHERE population > 10000 ").show()
# Out:
# ┌───────────┬────────────┐
# │ room_type │ population │
# │  double   │   int64    │
# ├───────────┼────────────┤
# │  1.789474 │      18238 │
# │  1.533333 │      21929 │
# │  1.615385 │      17841 │
# │  1.436364 │      39493 │
# │      1.75 │      11717 │
# │  1.587156 │      25681 │
# │  1.958333 │      25983 │
# │  1.645669 │      54991 │
# │       1.5 │      25448 │
# │       2.0 │      18508 │
# │        ·  │        ·   │
# │        ·  │        ·   │
# │        ·  │        ·   │
# │  1.343575 │      64116 │
# │       1.5 │      41081 │
# │       2.0 │      48743 │
# │  1.571429 │      20034 │
# │      NULL │      26493 │
# │      NULL │      19093 │
# │       1.0 │      22544 │
# │       2.5 │      12756 │
# │  1.582353 │      56521 │
# │       1.0 │      11187 │
# ├───────────┴────────────┤
# │ 71 rows      2 columns │
# │ (20 shown)             │
# └────────────────────────┘
