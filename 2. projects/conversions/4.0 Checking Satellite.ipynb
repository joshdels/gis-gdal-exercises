# %% [markdown]
# Raster CLI and API sidebyside

# %%
import os
import geopandas as gpd

os.environ['PROJ_LIB'] = r"C:\Users\deleo\miniconda3\envs\webgisbackend\Library\share\proj"
os.chdir(r"C:\Users\deleo\Downloads\conversion\phl_schp_deped")
os.getcwd()
# Out:
# 'C:\\Users\\deleo\\Downloads\\conversion\\phl_schp_deped'

# %%
gdf = gpd.read_file("phl_schp_deped.shp").to_crs(epsg=4326)
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 gdf = gpd.read_file("phl_schp_deped.shp").to_crs(epsg=4326)
#
# File c:\Users\deleo\miniconda3\envs\webgisbackend\Lib\site-packages\geopandas\geodataframe.py:1847, in GeoDataFrame.to_crs(self, crs, epsg, inplace)
#    1845 else:
#    1846     df = self.copy()
# -> 1847 geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1848 df.geometry = geom
#    1849 if not inplace:
#
# File c:\Users\deleo\miniconda3\envs\webgisbackend\Lib\site-packages\geopandas\geoseries.py:1251, in GeoSeries.to_crs(self, crs, epsg)
#    1174 def to_crs(self, crs: Any | None = None, epsg: int | None = None) -> GeoSeries:
#    1175     """Return a ``GeoSeries`` with all geometries transformed to a new
#    1176     coordinate reference system.
#    1177
#    (...)   1248
#    1249     """
#    1250     return GeoSeries(
# ...

# %%
from pyproj import CRS
print(CRS.from_epsg(4326))
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 from pyproj import CRS
# ----> 2 print(CRS.from_epsg(4326))
#
# File c:\Users\deleo\miniconda3\envs\webgisbackend\Lib\site-packages\pyproj\crs\crs.py:394, in CRS.from_epsg(cls, code)
#     381 @classmethod
#     382 def from_epsg(cls, code: str | int) -> "CRS":
#     383     """Make a CRS from an EPSG code
#     384
#     385     Parameters
#    (...)    392     CRS
#     393     """
# --> 394     return cls.from_user_input(_prepare_from_epsg(code))
#
# File c:\Users\deleo\miniconda3\envs\webgisbackend\Lib\site-packages\pyproj\crs\crs.py:503, in CRS.from_user_input(cls, value, **kwargs)
#     501 if isinstance(value, cls):
#     502     return value
# --> 503 return cls(value, **kwargs)
#
# ...

# %%
print("PROJ_LIB =", os.environ.get("PROJ_LIB"))
# Out:
# PROJ_LIB = C:\Users\deleo\miniconda3\envs\webgisbackend\Library\share\proj
